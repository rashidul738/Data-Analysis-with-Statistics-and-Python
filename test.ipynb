# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

# %%
sample_mean = 20
z_value = 1.96  # for 95% confidence level
standard_error = 5 / np.sqrt(30)
